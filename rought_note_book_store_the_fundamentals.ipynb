# %%
lp = dbutils.fs.ls("/Volumes/engineering/bronze/raw_data_sources/source_crm/")

# %%
[name.name for name in lp]

# %%
# %sql
select * from engineering.bronze.crm_cust_info
limit 10

# %%
display(spark.read.table("engineering.bronze.crm_prd_info"))

# %%
display(spark.read.table("engineering.bronze.crm_sales_details").limit(10))

# %%
display(spark.read.table("engineering.bronze.erp_cust_az12").limit(10))

# %%
display(spark.read.table("engineering.bronze.erp_loc_a101").limit(10))

# %%
display(spark.read.table("engineering.bronze.erp_px_cat_g1v2"))
